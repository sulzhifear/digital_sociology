# %% [markdown]
# Pandas позволяет загружать данные из различных форматов: текстовых файлов, бинарных,баз данных.
# Pandas оперируют двумя основными структурами данных. Series и DataFrame.
# Series - индексированный массив некоторого типа: числовой, бинарный или категориальный.
# DataFrame - двумерная структура данных, совокупность Series.

# %% [markdown]
# # Работа с Pandas Series

# %% [markdown]
# #### Импортируем Pandas и создадим Series объект c указанием индексов

# %%
import pandas as pd
s = pd.Series([1,2,3,4], index=['a', 'b', 'c', 'd'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# #### без указания индексов

# %%
s1 = pd.Series([1,2,3,4])

# %%
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# #### Можно передать словарь для созданиея Series

# %%
d = {'Moscow': 1000, 'London' : 300, 'Paris': 100}
cities = pd.Series(d)

# %%
cities
# Out:
# Moscow    1000
# London     300
# Paris      100
# dtype: int64

# %% [markdown]
# #### Достем знаечение по индексу

# %%
cities['Moscow']
# Out:
# 1000

# %%
cities[['Moscow', 'Paris']]
# Out:
# Moscow    1000
# Paris      100
# dtype: int64

# %%
cities < 1000
# Out:
# Moscow    False
# London     True
# Paris      True
# dtype: bool

# %% [markdown]
# #### условие мы можем передать как индекс

# %%
cities[cities < 1000]
# Out:
# London    300
# Paris     100
# dtype: int64

# %% [markdown]
# #### Как поменять значение в Series?

# %%
cities['Moscow'] = 1100

# %%
cities['Moscow']
# Out:
# 1100

# %% [markdown]
# #### Присвоить новые значения множеству элементов

# %%
cities[cities < 1000] = "Новые значения для всех элементов меньше 1000"

# %%
cities
# Out:
# Moscow                                             1100
# London    Новые значения для всех элементов меньше 1000
# Paris     Новые значения для всех элементов меньше 1000
# dtype: object

# %% [markdown]
# #### умножение всех элементов на число

# %%
cities * 3
# Out:
# Moscow                                                 3300
# London    Новые значения для всех элементов меньше 1000Н...
# Paris     Новые значения для всех элементов меньше 1000Н...
# dtype: object

# %%
cities = [cities.isnull()]

# %%
cities
# Out:
# [Moscow    False
#  London    False
#  Paris     False
#  dtype: bool]

# %% [markdown]
# # Работа с Pandas Dataframe

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Размер, типы данных, названия столбцов

# %% [markdown]
# ### Загрузим датасет лента_ру

# %%
filename = 'D:\data_set\lenta-ru-news.csv'

# %%
df = pd.read_csv(filename) #открывает csv
df.head(10) #возвращает первые 10 строк нашего датафрейма
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                              url  \
# 0     https://lenta.ru/news/1914/09/16/hungarnn/
# 1    https://lenta.ru/news/1914/09/16/lermontov/
# 2    https://lenta.ru/news/1914/09/17/nesteroff/
# 3     https://lenta.ru/news/1914/09/17/bulldogn/
# 4         https://lenta.ru/news/1914/09/18/zver/
# 5  https://lenta.ru/news/1999/08/31/stancia_mir/
# 6        https://lenta.ru/news/1999/08/31/vzriv/
# 7  https://lenta.ru/news/1999/08/31/credit_japs/
# 8        https://lenta.ru/news/1999/08/31/diana/
# 9          https://lenta.ru/news/1999/08/31/mvf/
#
#                                                title  \
# 0  1914. Русские войска вступили в пределы Венгрии
# 1  1914. Празднование столетия М.Ю. Лермонтова от...
# 2                           1914. Das ist Nesteroff!
# 3                    1914. Бульдог-гонец под Льежем
# 4           1914. Под Люблином пойман швабский зверь
# 5         Космонавты сомневаются в надежности "Мира"
# 6       Взрыв в центре Москвы: пострадало 30 человек
# 7  Япония кредитует Россию на полтора миллиарда д...
# 8           Британцы отмечают двухлетие смерти Дианы
# 9  Отмытые через Bank of NY деньги не имели отнош...
#
#                                                 text       topic  \
# 0  Бои у Сопоцкина и Друскеник закончились отступ...  Библиотека
# 1  Министерство народного просвещения, в виду про...  Библиотека
# 2  Штабс-капитан П. Н. Нестеров на днях, увидев в...  Библиотека
# 3  Фотограф-корреспондент Daily Mirror рассказыва...  Библиотека
# 4  Лица, приехавшие в Варшаву из Люблина, передаю...  Библиотека
# 5  Как стало известно агентству Ассошиэйтед Пресс...      Россия
# 6  В зале игровых автоматов в третьем ярусе подзе...      Россия
# 7  Япония приняла решение разморозить кредиты Рос...      Россия
# 8  Британцы отмечают сегодня скорбную дату - втор...         Мир
# 9  В понедельник директор департамента внешних св...      Россия
#
#              tags        date
# 0  Первая мировая  1914/09/16
# 1  Первая мировая  1914/09/16
# 2  Первая мировая  1914/09/17
# 3  Первая мировая  1914/09/17
# 4  Первая мировая  1914/09/18
# 5             Все  1999/08/31
# 6             Все  1999/08/31
# 7             Все  1999/08/31
# 8             Все  1999/08/31
# 9             Все  1999/08/31

# %% [markdown]
# ## Случайный отбор десяти элементов, метод sample()

# %%
sample_df = df.sample(10) #frac = 0.1 - доля от датасета

# %%
sample_df
# Out:
#                                                url  \
# 339575   https://lenta.ru/news/2010/07/29/voronej/
# 377248     https://lenta.ru/news/2011/06/06/bucnh/
# 483045    https://lenta.ru/news/2013/10/14/chelny/
# 787898   https://lenta.ru/news/2019/10/11/finally/
# 204433   https://lenta.ru/news/2007/10/18/foreign/
# 639938      https://lenta.ru/news/2017/01/13/utro/
# 214007     https://lenta.ru/news/2008/01/22/green/
# 437636        https://lenta.ru/news/2012/10/04/er/
# 64456   https://lenta.ru/news/2003/01/21/snowshow/
# 573256       https://lenta.ru/news/2015/12/15/car/
#
#                                                     title  \
# 339575  Часть Воронежа осталась без света из-за лесных...
# 377248  Шерлок Холмс станет аристократом времен Первой...
# 483045  В Набережных Челнах убили активистку движения ...
# 787898  Федор Емельяненко спланировал последний бой в ...
# 204433  "12" Михалкова поборются за "Оскар" с 62 конку...
# 639938    В Норильске и Дудинке завершилась полярная ночь
# 214007  Крупнейшая компьютерная выставка мира "позелен...
# 437636  "Единая Россия" обжаловала передачу мандата Гу...
# 64456      Вячеслав Полунин привез в Москву "Снежное шоу"
# 573256  Навальный сообщил подробности проверки его док...
#
#                                                      text            topic  \
# 339575  Некоторые пригороды Воронежа остались без свет...              Мир
# 377248  Британские актеры Бенедикт Камбербэтч и Ребекк...         Культура
# 483045  В Набережных Челнах убита одна из лидеров мест...           Россия
# 787898  Российский боец смешанного стиля (ММА) Федор Е...              NaN
# 204433  63 государства выдвинули свои картины на преми...         Культура
# 639938  В Норильске и Дудинке закончилась полярная ноч...   69-я параллель
# 214007  Участники CeBIT, крупнейшей компьютерной выста...  Наука и техника
# 437636  Депутаты Госдумы от "Единой России" обратились...           Россия
# 64456   Известный клоун Вячеслав Полунин приехал в Мос...         Культура
# 573256  Глава Фонда борьбы с коррупцией (ФБК), лидер «...           Россия
#
#               tags        date
# 339575         Все  2010/07/29
# 377248         Все  2011/06/06
# 483045         NaN  2013/10/14
# 787898  Бокс и ММА  2019/10/11
# 204433         Все  2007/10/18
# 639938     События  2017/01/13
# 214007         Все  2008/01/22
# 437636         Все  2012/10/04
# 64456          Все  2003/01/21
# 573256    Политика  2015/12/15

# %% [markdown]
# ### Последние строки датафрейма

# %%
df.tail(2)
# Out:
#                                             url  \
# 800973  https://lenta.ru/news/2019/12/14/meteo/
# 800974  https://lenta.ru/news/2019/12/14/olimp/
#
#                                                     title  \
# 800973        Россиянам пообещали аномально теплую погоду
# 800974  В конкурсе прогнозов на АПЛ разыграют 100 тыся...
#
#                                                      text topic  \
# 800973  В ближайшие дни в европейской части России пог...   NaN
# 800974  Ведущие футбольные чемпионаты ушли на зимние к...   NaN
#
#                      tags        date
# 800973           Общество  2019/12/14
# 800974  Английский футбол  2019/12/14

# %% [markdown]
# ## Размеры датафрейма shape

# %% [markdown]
# shape(число строк, число столбцов)

# %%
df.shape
# Out:
# (800975, 6)

# %% [markdown]
# названия столбцов

# %%
df.columns
# Out:
# Index(['url', 'title', 'text', 'topic', 'tags', 'date'], dtype='object')

# %% [markdown]
# типы данных

# %%
df.dtypes
# Out:
# url      object
# title    object
# text     object
# topic    object
# tags     object
# date     object
# dtype: object

# %% [markdown]
# Вывести необходимые столбцы

# %%
df[['date', 'title']]
# Out:
#               date                                              title
# 0       1914/09/16  1914. Русские войска вступили в пределы Венгрии
# 1       1914/09/16  1914. Празднование столетия М.Ю. Лермонтова от...
# 2       1914/09/17                           1914. Das ist Nesteroff!
# 3       1914/09/17                    1914. Бульдог-гонец под Льежем
# 4       1914/09/18           1914. Под Люблином пойман швабский зверь
# ...            ...                                                ...
# 800970  2019/12/14          Шнуров раскритиковал Гагарину на «Голосе»
# 800971  2019/12/14  В России предложили изменить правила взыскания...
# 800972  2019/12/14          В России назвали «черную дату» для Европы
# 800973  2019/12/14        Россиянам пообещали аномально теплую погоду
# 800974  2019/12/14  В конкурсе прогнозов на АПЛ разыграют 100 тыся...
#
# [800975 rows x 2 columns]

# %% [markdown]
# ## Обращение к элементам датафрейма loc/iloc

# %%
df.iloc[-1] #обращение к последнему элементу
# Out:
# url                https://lenta.ru/news/2019/12/14/olimp/
# title    В конкурсе прогнозов на АПЛ разыграют 100 тыся...
# text     Ведущие футбольные чемпионаты ушли на зимние к...
# topic                                                  NaN
# tags                                     Английский футбол
# date                                            2019/12/14
# Name: 800974, dtype: object

# %%
df.loc[1, 'text']
# Out:
# 'Министерство народного просвещения, в виду происходящих чрезвычайных событий, признало соответственным в день годовщины со дня рождения М.Ю. Лермонтова (2-го октября 1914 года) ограничиться совершением в учебных заведениях панихиды по поэту, отложив празднование юбилея до более благоприятного времени.  \n«Русский инвалид», 16 сентября 1914 года.'

# %%
df.iloc[0:6, 0:4] #[от первого до пятого элемента, по четырем столбцам]
# Out:
#                                              url  \
# 0     https://lenta.ru/news/1914/09/16/hungarnn/
# 1    https://lenta.ru/news/1914/09/16/lermontov/
# 2    https://lenta.ru/news/1914/09/17/nesteroff/
# 3     https://lenta.ru/news/1914/09/17/bulldogn/
# 4         https://lenta.ru/news/1914/09/18/zver/
# 5  https://lenta.ru/news/1999/08/31/stancia_mir/
#
#                                                title  \
# 0  1914. Русские войска вступили в пределы Венгрии
# 1  1914. Празднование столетия М.Ю. Лермонтова от...
# 2                           1914. Das ist Nesteroff!
# 3                    1914. Бульдог-гонец под Льежем
# 4           1914. Под Люблином пойман швабский зверь
# 5         Космонавты сомневаются в надежности "Мира"
#
#                                                 text       topic
# 0  Бои у Сопоцкина и Друскеник закончились отступ...  Библиотека
# 1  Министерство народного просвещения, в виду про...  Библиотека
# 2  Штабс-капитан П. Н. Нестеров на днях, увидев в...  Библиотека
# 3  Фотограф-корреспондент Daily Mirror рассказыва...  Библиотека
# 4  Лица, приехавшие в Варшаву из Люблина, передаю...  Библиотека
# 5  Как стало известно агентству Ассошиэйтед Пресс...      Россия

# %%
df.loc[0:6,'text']
# Out:
# 0    Бои у Сопоцкина и Друскеник закончились отступ...
# 1    Министерство народного просвещения, в виду про...
# 2    Штабс-капитан П. Н. Нестеров на днях, увидев в...
# 3    Фотограф-корреспондент Daily Mirror рассказыва...
# 4    Лица, приехавшие в Варшаву из Люблина, передаю...
# 5    Как стало известно агентству Ассошиэйтед Пресс...
# 6    В зале игровых автоматов в третьем ярусе подзе...
# Name: text, dtype: object

# %%
df.loc[0:6, 'url':'text']
# Out:
#                                              url  \
# 0     https://lenta.ru/news/1914/09/16/hungarnn/
# 1    https://lenta.ru/news/1914/09/16/lermontov/
# 2    https://lenta.ru/news/1914/09/17/nesteroff/
# 3     https://lenta.ru/news/1914/09/17/bulldogn/
# 4         https://lenta.ru/news/1914/09/18/zver/
# 5  https://lenta.ru/news/1999/08/31/stancia_mir/
# 6        https://lenta.ru/news/1999/08/31/vzriv/
#
#                                                title  \
# 0  1914. Русские войска вступили в пределы Венгрии
# 1  1914. Празднование столетия М.Ю. Лермонтова от...
# 2                           1914. Das ist Nesteroff!
# 3                    1914. Бульдог-гонец под Льежем
# 4           1914. Под Люблином пойман швабский зверь
# 5         Космонавты сомневаются в надежности "Мира"
# 6       Взрыв в центре Москвы: пострадало 30 человек
#
#                                                 text
# 0  Бои у Сопоцкина и Друскеник закончились отступ...
# 1  Министерство народного просвещения, в виду про...
# 2  Штабс-капитан П. Н. Нестеров на днях, увидев в...
# 3  Фотограф-корреспондент Daily Mirror рассказыва...
# 4  Лица, приехавшие в Варшаву из Люблина, передаю...
# 5  Как стало известно агентству Ассошиэйтед Пресс...
# 6  В зале игровых автоматов в третьем ярусе подзе...

# %% [markdown]
# ## Фильтрация

# %% [markdown]
# ## Статистика по датафрейму

# %% [markdown]
# ### описательная статистика

# %%
df.describe()
# Out:
#                                             url  \
# count                                    800975
# unique                                   800964
# top     https://lenta.ru/news/1999/11/12/china/
# freq                                          2
#
#                                               title           text   topic  \
# count                                        800975         800970  738973
# unique                                       797832         800037      23
# top     В Москве объявлено штормовое предупреждение  РИА "Новости"  Россия
# freq                                             21            291  160445
#
#           tags        date
# count   773756      800975
# unique      94        7393
# top        Все  2019/12/05
# freq    453762         284

# %% [markdown]
# ### описательная статистика по категориям

# %%
df.describe(include=[np.object])
# Out:
#                                             url  \
# count                                    800975
# unique                                   800964
# top     https://lenta.ru/news/1999/11/12/china/
# freq                                          2
#
#                                               title           text   topic  \
# count                                        800975         800970  738973
# unique                                       797832         800037      23
# top     В Москве объявлено штормовое предупреждение  РИА "Новости"  Россия
# freq                                             21            291  160445
#
#           tags        date
# count   773756      800975
# unique      94        7393
# top        Все  2019/12/05
# freq    453762         284

# %% [markdown]
# ### Статистика по значениям внутри столбца

# %%
df['topic'].value_counts() #(normalize='True' - нормализованное значение), подсчет значений
# Out:
# Россия               160445
# Мир                  136621
# Экономика             79528
# Спорт                 64413
# Культура              53797
# Бывший СССР           53402
# Наука и техника       53136
# Интернет и СМИ        44663
# Из жизни              27605
# Дом                   21734
# Силовые структуры     19596
# Ценности               7766
# Бизнес                 7399
# Путешествия            6408
# 69-я параллель         1268
# Крым                    666
# Культпросвет            340
# Легпром                 114
# Библиотека               65
# Оружие                    3
# ЧМ-2014                   2
# Сочи                      1
# МедНовости                1
# Name: topic, dtype: int64

# %%
df['topic'].unique() #показывает уникальные значнеия внутри столбца
# Out:
# array(['Библиотека', 'Россия', 'Мир', 'Экономика', 'Интернет и СМИ',
#        'Спорт', 'Культура', 'Из жизни', 'Силовые структуры',
#        'Наука и техника', 'Бывший СССР', nan, 'Дом', 'Сочи', 'ЧМ-2014',
#        'Путешествия', 'Ценности', 'Легпром', 'Бизнес', 'МедНовости',
#        'Оружие', '69-я параллель', 'Культпросвет ', 'Крым'], dtype=object)

# %% [markdown]
# ## запись в csv

# %% [markdown]
# df.to_csv('path.csv')

# %% [markdown]
# # Группировка данных

# %%
filename1 = r'D:\data_set\trip.csv'
df_1 = pd.read_csv(filename1)

# %% [markdown]
# ## Корреляция между всеми столбцами датасета

# %%
df_1.corr()
# Out:
#                          tripduration  start station id  \
# tripduration                 1.000000          0.004856
# start station id             0.004856          1.000000
# start station latitude       0.000245         -0.069213
# start station longitude     -0.014859          0.154120
# end station id              -0.008593          0.202527
# end station latitude         0.017355          0.010946
# end station longitude       -0.006029          0.104313
# bikeid                       0.002824         -0.002310
# birth year                  -0.027262          0.003075
# gender                      -0.048734         -0.009058
#
#                          start station latitude  start station longitude  \
# tripduration                           0.000245                -0.014859
# start station id                      -0.069213                 0.154120
# start station latitude                 1.000000                -0.059304
# start station longitude               -0.059304                 1.000000
# end station id                        -0.003656                 0.089409
# end station latitude                   0.469655                -0.058688
# end station longitude                 -0.064007                 0.562555
# bikeid                                -0.009277                -0.004985
# birth year                             0.048900                -0.005326
# gender                                 0.018902                 0.015141
#
#                          end station id  end station latitude  \
# tripduration                  -0.008593              0.017355
# start station id               0.202527              0.010946
# start station latitude        -0.003656              0.469655
# start station longitude        0.089409             -0.058688
# end station id                 1.000000             -0.056424
# end station latitude          -0.056424              1.000000
# end station longitude          0.136101             -0.016781
# bikeid                        -0.003534             -0.008268
# birth year                     0.005937              0.050188
# gender                        -0.006858              0.011906
#
#                          end station longitude    bikeid  birth year    gender
# tripduration                         -0.006029  0.002824   -0.027262 -0.048734
# start station id                      0.104313 -0.002310    0.003075 -0.009058
# start station latitude               -0.064007 -0.009277    0.048900  0.018902
# start station longitude               0.562555 -0.004985   -0.005326  0.015141
# end station id                        0.136101 -0.003534    0.005937 -0.006858
# end station latitude                 -0.016781 -0.008268    0.050188  0.011906
# end station longitude                 1.000000 -0.005674    0.005399  0.025504
# bikeid                               -0.005674  1.000000   -0.010374  0.015008
# birth year                            0.005399 -0.010374    1.000000  0.513522
# gender                                0.025504  0.015008    0.513522  1.000000

# %% [markdown]
# ### Группировка значений в датафрейме

# %%
df_1.groupby(['usertype']).groups #внутри лежат индексы строк, в которых представлены значения
# Out:
# {'Customer': Int64Index([    5,     8,    14,    15,    16,    17,    18,    19,    21,
#                 38,
#              ...
#              36911, 36912, 36913, 36914, 36915, 36916, 36917, 36918, 36919,
#              36920],
#             dtype='int64', length=17096),
#  'Subscriber': Int64Index([    0,     1,     2,     3,     4,     6,     7,     9,    10,
#                 11,
#              ...
#              36897, 36898, 36899, 36900, 36902, 36904, 36905, 36906, 36907,
#              36908],
#             dtype='int64', length=19825)}

# %%
df_1.groupby(['usertype']).first() #показывает первые значения в каждой группе
# Out:
#             tripduration                 starttime                  stoptime  \
# usertype
# Customer             278  2020-06-01 01:27:38.7630  2020-06-01 01:32:17.4570
# Subscriber           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
#
#             start station id          start station name  \
# usertype
# Customer                3639                  Harborside
# Subscriber              3792  Columbus Dr at Exchange Pl
#
#             start station latitude  start station longitude  end station id  \
# usertype
# Customer                 40.719252               -74.034234            3186
# Subscriber               40.716870               -74.032810            3639
#
#            end station name  end station latitude  end station longitude  \
# usertype
# Customer      Grove St PATH             40.719586             -74.043117
# Subscriber       Harborside             40.719252             -74.034234
#
#             bikeid  birth year  gender
# usertype
# Customer     42300        1969       0
# Subscriber   42489        1987       1

# %% [markdown]
# ### группировка и среднее значение (таблица)

# %%
df_1.groupby(['usertype'])[['tripduration']].mean()#([первый элемент])[[второй элемент]]
# Out:
#             tripduration
# usertype
# Customer     3651.805276
# Subscriber   1127.921009

# %% [markdown]
# ### таблица по трем признакам

# %%
df_1.groupby(['usertype', 'start station name'])[['tripduration']].mean()#([первый элемент])[[второй элемент]]
# Out:
#                                   tripduration
# usertype   start station name
# Customer   5 Corners Library       2696.471698
#            Astor Place             3603.830645
#            Baldwin at Montgomery   2532.252101
#            Bergen Ave             16169.614458
#            Brunswick & 6th         1628.945652
# ...                                        ...
# Subscriber Union St                1606.817518
#            Van Vorst Park          1121.712000
#            Warren St                919.360558
#            Washington St           1224.987041
#            York St                 1025.628019
#
# [102 rows x 1 columns]

# %% [markdown]
# ### аггрегация данных

# %%
df_1.groupby(['usertype']).agg({'tripduration' : sum, 'starttime':'first'})
# Out:
#             tripduration                 starttime
# usertype
# Customer        62431263  2020-06-01 01:27:38.7630
# Subscriber      22361034  2020-06-01 00:02:21.7500

# %%
df_1.groupby(['usertype']).agg({'tripduration' : [sum, min], 
                                'starttime':'first'})
# Out:
#            tripduration                     starttime
#                     sum min                     first
# usertype
# Customer       62431263  61  2020-06-01 01:27:38.7630
# Subscriber     22361034  61  2020-06-01 00:02:21.7500

# %%
df_1.groupby(['usertype']).agg({'tripduration' : lambda x: max(x) + 1, 
                                'starttime':'first'})
# Out:
#             tripduration                 starttime
# usertype
# Customer         1554398  2020-06-01 01:27:38.7630
# Subscriber        631696  2020-06-01 00:02:21.7500

# %%
sample_df = df.sample(10)

# %%
print(type(sample_df))
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
import nltk
import nltk.corpus
from nltk.tokenize import word_tokenize
from string import punctuation
from nltk.corpus import stopwords
import pymorphy2
punctuation = '—'.join(punctuation)
punctuation = '«'.join(punctuation)
punctuation = '»'.join(punctuation)
punctuation = "„".join(punctuation)
punctuation = '“'.join(punctuation)
morph = pymorphy2.MorphAnalyzer()
stopwords = stopwords.words('russian') + [a for a in punctuation]

# %%
def tokenizer(text):
    tokens_clean = []
    tokens = word_tokenize(text = text)
    for token in tokens:
        if token not in stopwords:
            form = morph.parse(token)[0].normal_form
            tokens_clean.append(form)
    return tokens_clean

# %%
sample_df
# Out:
#                                                   url  \
# 82701   https://lenta.ru/news/2003/11/25/hodorkovsky/
# 534012      https://lenta.ru/news/2015/01/31/vatican/
# 240090       https://lenta.ru/news/2008/08/04/nvidia/
# 506847      https://lenta.ru/news/2014/06/07/zvezda1/
# 524192      https://lenta.ru/news/2014/11/13/tezdebt/
# 388653         https://lenta.ru/news/2011/09/08/time/
# 305393     https://lenta.ru/news/2009/10/30/aquarium/
# 778398       https://lenta.ru/news/2019/08/26/ssj100/
# 99965         https://lenta.ru/news/2004/08/30/bonus/
# 791358        https://lenta.ru/news/2019/10/29/otvet/
#
#                                                     title  \
# 82701   Завершено следствие по делу Михаила Ходорковского
# 534012               В Ватикане нашли детскую порнографию
# 240090     Nvidia не планирует прекращать выпуск чипсетов
# 506847  Задержанных на Украине журналистов «Звезды» за...
# 524192         В «Аэрофлоте» назвали сумму долга TEZ Tour
# 388653  Журнал Time отметит десятую годовщину 11 сентя...
# 305393  "Аквариум" отменил концерт из-за подозрения на...
# 778398  Sukhoi Superjet оказался кому-то нужен после а...
# 99965   В России будет 40 научных премий по миллиону р...
# 791358  Россия пообещала ответить на высылку дипломата...
#
#                                                      text            topic  \
# 82701   Генпрокуратура России завершила предварительно...           Россия
# 534012  В Ватикане обнаружена детская порнография. Об ...              Мир
# 240090  Компания Nvidia опровергла информацию о том, ч...  Наука и техника
# 506847  Журналистов российского телеканала «Звезда» за...      Бывший СССР
# 524192  «Аэрофлот» отключил TEZ Tour от системы бронир...        Экономика
# 388653  Журнал Time отметит десятую годовщину терактов...   Интернет и СМИ
# 305393  Борис Гребенщиков и группа "Аквариум" отменили...         Культура
# 778398  Министр промышленности и торговли Денис Мантур...              NaN
# 99965   Начиная с 2005 года, в России будет вручаться ...           Россия
# 791358  Россия ответит на высылку своего дипломата из ...              NaN
#
#                 tags        date
# 82701            Все  2003/11/25
# 534012      Общество  2015/01/31
# 240090           Все  2008/08/04
# 506847       Украина  2014/06/07
# 524192        Бизнес  2014/11/13
# 388653           Все  2011/09/08
# 305393           Все  2009/10/30
# 778398  Госэкономика  2019/08/26
# 99965            Все  2004/08/30
# 791358      Политика  2019/10/29

# %%
# %%time
sample_df['clean'] = sample_df['text'].apply(tokenizer)
sample_df
# Out:
# Wall time: 262 ms
#                                                   url  \
# 82701   https://lenta.ru/news/2003/11/25/hodorkovsky/
# 534012      https://lenta.ru/news/2015/01/31/vatican/
# 240090       https://lenta.ru/news/2008/08/04/nvidia/
# 506847      https://lenta.ru/news/2014/06/07/zvezda1/
# 524192      https://lenta.ru/news/2014/11/13/tezdebt/
# 388653         https://lenta.ru/news/2011/09/08/time/
# 305393     https://lenta.ru/news/2009/10/30/aquarium/
# 778398       https://lenta.ru/news/2019/08/26/ssj100/
# 99965         https://lenta.ru/news/2004/08/30/bonus/
# 791358        https://lenta.ru/news/2019/10/29/otvet/
#
#                                                     title  \
# 82701   Завершено следствие по делу Михаила Ходорковского
# 534012               В Ватикане нашли детскую порнографию
# 240090     Nvidia не планирует прекращать выпуск чипсетов
# 506847  Задержанных на Украине журналистов «Звезды» за...
# 524192         В «Аэрофлоте» назвали сумму долга TEZ Tour
# 388653  Журнал Time отметит десятую годовщину 11 сентя...
# 305393  "Аквариум" отменил концерт из-за подозрения на...
# 778398  Sukhoi Superjet оказался кому-то нужен после а...
# 99965   В России будет 40 научных премий по миллиону р...
# 791358  Россия пообещала ответить на высылку дипломата...
#
#                                                      text            topic  \
# 82701   Генпрокуратура России завершила предварительно...           Россия
# 534012  В Ватикане обнаружена детская порнография. Об ...              Мир
# 240090  Компания Nvidia опровергла информацию о том, ч...  Наука и техника
# 506847  Журналистов российского телеканала «Звезда» за...      Бывший СССР
# 524192  «Аэрофлот» отключил TEZ Tour от системы бронир...        Экономика
# 388653  Журнал Time отметит десятую годовщину терактов...   Интернет и СМИ
# 305393  Борис Гребенщиков и группа "Аквариум" отменили...         Культура
# 778398  Министр промышленности и торговли Денис Мантур...              NaN
# 99965   Начиная с 2005 года, в России будет вручаться ...           Россия
# 791358  Россия ответит на высылку своего дипломата из ...              NaN
#
#                 tags        date  \
# 82701            Все  2003/11/25
# 534012      Общество  2015/01/31
# 240090           Все  2008/08/04
# 506847       Украина  2014/06/07
# 524192        Бизнес  2014/11/13
# 388653           Все  2011/09/08
# 305393           Все  2009/10/30
# 778398  Госэкономика  2019/08/26
# 99965            Все  2004/08/30
# 791358      Политика  2019/10/29
#
#                                                     clean
# 82701   [генпрокуратура, россия, завершить, предварите...
# 534012  [в, ватикан, обнаружить, детский, порнография,...
# 240090  [компания, nvidia, опровергнуть, информация, н...
# 506847  [журналист, российский, телеканал, звезда, зад...
# 524192  [аэрофлот, отключить, tez, tour, система, брон...
# 388653  [журнал, time, отметить, десять, годовщина, те...
# 305393  [борис, гребенщик, группа, ``, аквариум, '', о...
# 778398  [министр, промышленность, торговля, денис, ман...
# 99965   [начинать, 2005, год, россия, вручаться, 40, п...
# 791358  [россия, ответить, высылка, свой, дипломат, бо...

# %%
# Out:
#   File "<ipython-input-62-2e128b52a428>", line 2
#     lambda sample_df['clean']: all_tokens.append(sample_df['clean'][i])
#                     ^
# SyntaxError: invalid syntax

# %%
all_tokens_list = []
for i in sample_df['clean']:
    all_tokens_list.append(i)
all_tokens_list
# Out:
# [['генпрокуратура',
#   'россия',
#   'завершить',
#   'предварительный',
#   'следствие',
#   'уголовный',
#   'дело',
#   'отношение',
#   'бывший',
#   'глава',
#   'нк',
#   '``',
#   'юкос',
#   "''",
#   'михаил',
#   'ходорковский',
#   'о',
#   'ходорковский',
#   'объявить',
#   '25',
#   'ноябрь',
#   'присутствие',
#   'адвокат',
#   'сообщить',
#   'информационный',
#   'агентство',
#   '``',
#   'интерфакс',
#   "''",
#   'официальный',
#   'представитель',
#   'генпрокуратура',
#   'обвинять',
#   'вместе',
#   'адвокат',
#   'начинать',
#   'ознакомление',
#   'материал',
#   'дело',
#   'генпрокуратура',
#   'обвинять',
#   'ходорковский',
#   'семь',
#   'статья',
#   'уголовный',
#   'кодекс',
#   'россия',
#   'число',
#   'хищение',
#   'путём',
#   'мошенничество',
#   'крупный',
#   'размер',
#   'уклонение',
#   'уплата',
#   'налог',
#   'самый',
#   '``',
#   'юкос',
#   "''",
#   'лично',
#   'ходорковский',
#   'кроме',
#   'ходорковский',
#   'предъявить',
#   'обвинение',
#   'злостный',
#   'неисполнение',
#   'вступить',
#   'законный',
#   'сила',
#   'решение',
#   'суд',
#   'причинение',
#   'имущественный',
#   'ущерб',
#   'собственник',
#   'путём',
#   'обман',
#   'подделка',
#   'официальный',
#   'документ',
#   'совершенный',
#   'неоднократно',
#   'присвоение',
#   'растрата',
#   'михаил',
#   'ходорковский',
#   'задержать',
#   '25',
#   'октябрь',
#   '2003',
#   'год',
#   'новосибирск',
#   'доставить',
#   'москва',
#   'в',
#   'день',
#   'басманный',
#   'суд',
#   'москва',
#   'выдать',
#   'санкция',
#   'арест',
#   'с',
#   'тот',
#   'пора',
#   'ходорковский',
#   'находиться',
#   'стража',
#   'а',
#   '24',
#   'ноябрь',
#   'ежедневный',
#   'газета',
#   '``',
#   'коммерсант',
#   "''",
#   'опубликовать',
#   'текст',
#   'записка',
#   'отобрать',
#   'выход',
#   'сизый',
#   'адвокат',
#   'ходорковский',
#   'ольга',
#   'артюхов',
#   'этот',
#   'записка',
#   'который',
#   'сообщаться',
#   'написать',
#   'ходроковский',
#   '``',
#   'содержимый',
#   'инструкция',
#   'противодействие',
#   'следствие',
#   "''",
#   'отобрать',
#   'артюхин',
#   '11',
#   'ноябрь',
#   'как',
#   'заключать',
#   'газета',
#   'содержание',
#   'дать',
#   'записка',
#   'оказаться',
#   'распоряжение',
#   'издание',
#   'следовать',
#   'вряд',
#   'мочь',
#   'написать',
#   'ходорковский'],
#  ['в',
#   'ватикан',
#   'обнаружить',
#   'детский',
#   'порнография',
#   'о',
#   'сообщать',
#   'reuters',
#   'как',
#   'заявить',
#   'генпрокурор',
#   'папский',
#   'государство',
#   'джан',
#   'пьеро',
#   'милано',
#   'ведомство',
#   'расследовать',
#   'деликатный',
#   'случай',
#   'различный',
#   'степень',
#   'серьёзность',
#   'касаться',
#   'хранение',
#   'материал',
#   'содержимый',
#   'детский',
#   'порно',
#   'имя',
#   'подозревать',
#   'назвать',
#   'по',
#   'слово',
#   'официальный',
#   'представитель',
#   'ватикан',
#   'один',
#   'случай',
#   'речь',
#   'идти',
#   'йозеф',
#   'весоловский',
#   'бывший',
#   'архиепископ',
#   'первое',
#   'апостольский',
#   'нунций',
#   'лишить',
#   'сан',
#   'педофилия',
#   'скандал',
#   'связанный',
#   'обвинение',
#   'католический',
#   'священник',
#   'педофилия',
#   'начаться',
#   '2000-ха',
#   'год',
#   'в',
#   'частность',
#   '2002',
#   'год',
#   'бостон',
#   '80',
#   'священнослужитель',
#   'уличить',
#   'сексуальный',
#   'преступление',
#   'против',
#   'несовершеннолетний',
#   'в',
#   '2009',
#   'год',
#   'ирландия',
#   'опубликовать',
#   'доклад',
#   'основание',
#   'который',
#   'педофилия',
#   'инкриминироваться',
#   '46',
#   'священник',
#   'эпизод',
#   'касаться',
#   'период',
#   '1975',
#   '2004',
#   'год',
#   'пострадать',
#   'около',
#   'два',
#   'тысяча',
#   'ребёнок',
#   'причём',
#   'мальчик',
#   'становиться',
#   'жертва',
#   'раз',
#   'чаща',
#   'девочка'],
#  ['компания',
#   'nvidia',
#   'опровергнуть',
#   'информация',
#   'намерить',
#   'отказаться',
#   'производство',
#   'чипсет',
#   'сообщать',
#   'extremetech',
#   'ранее',
#   'издание',
#   'digitimes',
#   'ссылаться',
#   'информация',
#   'получить',
#   'производитель',
#   'системный',
#   'плата',
#   'сообщить',
#   'план',
#   'nvidia',
#   'уход',
#   'бизнес',
#   'выпуск',
#   'чипсет',
#   'представитель',
#   'nvidia',
#   'брайан',
#   'дель',
#   'риццо',
#   'bryan',
#   'del',
#   'rizzo',
#   'назвать',
#   'информация',
#   'прекращение',
#   'компания',
#   'выпуск',
#   'чипсет',
#   'беспочвенный',
#   'он',
#   'подчеркнуть',
#   'настоящее',
#   'время',
#   'позиция',
#   'nvidia',
#   'рынок',
#   'чипсет',
#   'платформа',
#   'intel',
#   'amd',
#   'крепкий',
#   'ранее',
#   'по',
#   'данные',
#   'компания',
#   'mercury',
#   'research',
#   'второе',
#   'квартал',
#   'текущий',
#   'год',
#   'доля',
#   'чипсет',
#   'nvidia',
#   'рынок',
#   'платформа',
#   'amd',
#   'составить',
#   '60',
#   'процент',
#   'кроме',
#   'риццо',
#   'заявить',
#   'ближний',
#   'время',
#   'nvidia',
#   'выпустить',
#   'новое',
#   'интересный',
#   'чипсет',
#   'платформа',
#   'intel',
#   'amd'],
#  ['журналист',
#   'российский',
#   'телеканал',
#   'звезда',
#   'задержать',
#   'восток',
#   'украина',
#   'боец',
#   'нацгвардия',
#   'передать',
#   'сотрудник',
#   'сбу',
#   'о',
#   'суббота',
#   'сообщить',
#   'пресс-служба',
#   'нацгвардия',
#   'журналист',
#   'подозревать',
#   'наблюдение',
#   'блокпост',
#   'украинский',
#   'силовик',
#   'сбор',
#   'информация',
#   'немой',
#   'сообщать',
#   'риа',
#   'новость',
#   'вчера',
#   'военнослужащий',
#   'национальный',
#   'гвардия',
#   'украина',
#   'вблизи',
#   'один',
#   'блокпост',
#   'зона',
#   'проведение',
#   'ато',
#   'подозрение',
#   'совершение',
#   'наблюдение',
#   'сбор',
#   'информация',
#   'организация',
#   'служба',
#   'блокпост',
#   'задержать',
#   'двое',
#   'журналист',
#   'российский',
#   'издание',
#   'звезда',
#   'который',
#   'иметь',
#   'документ',
#   'подтверждать',
#   'аккредитация',
#   'самопровозгласить',
#   'донецкий',
#   'народный',
#   'республика',
#   'говориться',
#   'сообщение',
#   'нацгвардия',
#   'журналист',
#   'российский',
#   'телеканал',
#   'звезда',
#   'курировать',
#   'минобороны',
#   'пропасть',
#   'обыск',
#   'проводить',
#   'нацгвардия',
#   'украина',
#   'подъезд',
#   'славянск',
#   'оператор',
#   'андрей',
#   'сушенковы',
#   'звукоинженер',
#   'антон',
#   'малышев',
#   'находиться',
#   'командировка',
#   'славянский',
#   'перестать',
#   'выходить',
#   'связь',
#   'пятница',
#   'днём',
#   'в',
#   'суббота',
#   '7',
#   'июнь',
#   'водитель',
#   'руслан',
#   'заславский',
#   'который',
#   'везти',
#   'журналист',
#   'донецк',
#   'славянск',
#   'рассказать',
#   'корреспондент',
#   'поставить',
#   'колено',
#   'надеть',
#   'голов',
#   'балаклава',
#   'затем',
#   'увезти',
#   'неизвестный',
#   'направление',
#   'самый',
#   'заславский',
#   'отпустить',
#   'несколько',
#   'часы',
#   'посольство',
#   'россия',
#   'киев',
#   'подготовить',
#   'обращение',
#   'обсе',
#   'связь',
#   'новый',
#   'захват',
#   'российский',
#   'журналист',
#   'территория',
#   'украина',
#   'к',
#   'работа',
#   'освобождение',
#   'сушенкова',
#   'малышев',
#   'также',
#   'подключиться',
#   'посольство',
#   'россия',
#   'украина',
#   'руководство',
#   'телеканал',
#   'обратиться',
#   'избранный',
#   'президент',
#   'украина',
#   'петра',
#   'порошенко',
#   'просьба',
#   'освободить',
#   'журналист'],
#  ['аэрофлот',
#   'отключить',
#   'tez',
#   'tour',
#   'система',
#   'бронирование',
#   'из-за',
#   'долг',
#   'о',
#   'тасс',
#   'заявить',
#   'представитель',
#   'авиакомпания',
#   'по',
#   'слово',
#   'задолженность',
#   'туроператор',
#   'аэрофлот',
#   'составлять',
#   '30',
#   'миллион',
#   'рубль',
#   'он',
#   'также',
#   'добавить',
#   'tez',
#   'tour',
#   'банковский',
#   'гарантия',
#   'предусмотренный',
#   'агент',
#   'который',
#   'работать',
#   'аэрофлот',
#   'представитель',
#   'перевозчик',
#   'уточнить',
#   'этот',
#   'гарантия',
#   'закончиться',
#   '2',
#   'ноябрь',
#   'турфирма',
#   'проинформировать',
#   'в',
#   'ситуация',
#   'соответствие',
#   'утвердить',
#   '``',
#   'аэрофлот',
#   "''",
#   'регламент',
#   'обязать',
#   'отключить',
#   'контрагент',
#   'система',
#   'бронирование',
#   'авиабилет',
#   'в',
#   'случай',
#   'получение',
#   'банковский',
#   'гарантия',
#   'компания',
#   'tez',
#   'tour',
#   '``',
#   'аэрофлот',
#   "''",
#   'готовый',
#   'возобновить',
#   'сотрудничество',
#   'данные',
#   'туроператор',
#   'подчеркнуть',
#   'при',
#   'гендиректор',
#   'tez',
#   'tour',
#   'владимир',
#   'каганер',
#   'сообщить',
#   'агентство',
#   'туроператор',
#   'долг',
#   'аэрофлот',
#   '12',
#   'ноябрь',
#   'стать',
#   'известно',
#   'аэрофлот',
#   'принять',
#   'решение',
#   'отключить',
#   'tez',
#   'tour',
#   'система',
#   'бронирование',
#   'авиабилет',
#   'каганер',
#   'сообщать',
#   'авиакомпания',
#   'отключить',
#   'система',
#   'бронирование',
#   'из-за',
#   'отказ',
#   'tez',
#   'tour',
#   'предоставить',
#   'жёсткий',
#   'гарантия',
#   'заполнение',
#   'самолёт',
#   'зимний',
#   'период',
#   'ранее',
#   'аэрофлот',
#   'отключить',
#   'система',
#   'бронирование',
#   'авиабилет',
#   'несколько',
#   'турфирма',
#   'среди',
#   'идеал-тур',
#   'капитал-тур',
#   'который',
#   'приостановить',
#   'деятельность',
#   'аэрофлот',
#   'tez',
#   'tour',
#   'сотрудничать',
#   '2000',
#   'год',
#   'tez',
#   'tour',
#   'основать',
#   '1994-метр',
#   'российский',
#   'бизнесмен',
#   'александр',
#   'буртин',
#   'александр',
#   'синигибский',
#   'также',
#   'турецкий',
#   'предприниматель',
#   'левентом',
#   'айдын',
#   'в',
#   'октябрь',
#   '2014',
#   'год',
#   'туроператор',
#   'сообщить',
#   'завершить',
#   'процесс',
#   'оптимизация',
#   'зимний',
#   'программа',
#   'планироваться',
#   'сократить',
#   'чартерный',
#   'рейс',
#   'большинство',
#   'направление',
#   'также',
#   'перевести',
#   'зимний',
#   'программа',
#   'регулярный',
#   'перевозка',
#   'авиакомпания',
#   'аэрофлот',
#   's7',
#   'трансаэро'],
#  ['журнал',
#   'time',
#   'отметить',
#   'десять',
#   'годовщина',
#   'теракт',
#   '11',
#   'сентябрь',
#   '2001',
#   'год',
#   'нью-йорк',
#   'специальный',
#   'номер',
#   'писать',
#   'the',
#   'guardian',
#   'этот',
#   'выпуск',
#   'журнал',
#   'обложка',
#   'который',
#   'увидеть',
#   'появиться',
#   'продажа',
#   'сша',
#   '8',
#   'сентябрь',
#   'о',
#   'содержание',
#   'номер',
#   'сообщаться',
#   'кроме',
#   'того-',
#   'начинаться',
#   'вступительный',
#   'статья',
#   'главный',
#   'редактор',
#   'ричард',
#   'стенгесть',
#   'в',
#   'статья',
#   'стенгел',
#   'писать',
#   'специальный',
#   'выпуск',
#   'time',
#   'это',
#   '``',
#   'уместный',
#   'способ',
#   'сохранить',
#   'память',
#   'мы',
#   'прийтись',
#   'пройти',
#   "''",
#   'помимо',
#   'номер',
#   'журналист',
#   'издание',
#   'подготовить',
#   'специальный',
#   'телепередача',
#   'посвятить',
#   'теракт',
#   'она',
#   'выйти',
#   'эфир',
#   'воскресение',
#   '11',
#   'сентябрь',
#   'крупный',
#   'американский',
#   'телеканал',
#   'как',
#   'сообщаться',
#   'блог',
#   'media',
#   'decoder',
#   'газета',
#   'the',
#   'new',
#   'york',
#   'times',
#   'передача',
#   'использовать',
#   'материал',
#   'интервью',
#   '40',
#   'человек',
#   'иначе',
#   'вовлечь',
#   'событие',
#   'происходить',
#   '11',
#   'сентябрь',
#   '2001',
#   'год',
#   'в',
#   'число',
#   'тот',
#   'человек',
#   'кто',
#   'побеседовать',
#   'журналист',
#   '43-ть',
#   'президент',
#   'сша',
#   'джордж',
#   'буш',
#   'занимать',
#   '2001',
#   'год',
#   'пост',
#   'министр',
#   'оборона',
#   'доналд',
#   'рамсфелд',
#   'бывший',
#   'мэр',
#   'нью-йорк',
#   'рудольф',
#   'джулиани',
#   'также',
#   'человек',
#   'случайно',
#   'оказаться',
#   'участник',
#   'событие',
#   'на',
#   'сайт',
#   'журнал',
#   'time',
#   'также',
#   'запустить',
#   'специальный',
#   'проект',
#   'память',
#   'событие',
#   'десятилетний',
#   'давность',
#   'название',
#   '``',
#   'отголосок',
#   '11',
#   'сентябрь',
#   'портрет',
#   'стойкость',
#   "''",
#   'кроме',
#   'десятилетие',
#   'день',
#   'теракт',
#   'журнал',
#   'выпустить',
#   'книга',
#   'написать',
#   'автор'],
#  ['борис',
#   'гребенщик',
#   'группа',
#   '``',
#   'аквариум',
#   "''",
#   'отменить',
#   'свой',
#   'концерт',
#   'санкт-петербург',
#   'из-за',
#   'болезнь',
#   'сразить',
#   'участник',
#   'коллектив',
#   'как',
#   'сообщать',
#   'фонтанка.р',
#   'музыкант',
#   'подозревать',
#   'грипп',
#   'h1n1',
#   'также',
#   'известный',
#   '``',
#   'свиной',
#   "''",
#   '30',
#   'октябрь',
#   '``',
#   'аквариум',
#   "''",
#   'вместе',
#   'ддт',
#   '``',
#   'ю-питер',
#   "''",
#   'должный',
#   'выступить',
#   'октябрьский',
#   'концертный',
#   'зал',
#   'честь',
#   '20-летний',
#   'юбилей',
#   'арт-центр',
#   '``',
#   'пушкинский',
#   '10',
#   "''",
#   'однако',
#   'вход',
#   'зал',
#   'зритель',
#   'встретить',
#   'объявление',
#   'выступление',
#   '``',
#   'аквариум',
#   "''",
#   'состояться',
#   'из-за',
#   'болезнь',
#   'борис',
#   'гребенщиков',
#   'как',
#   'выясниться',
#   'концерт',
#   '``',
#   'аквариум',
#   "''",
#   'иркутск',
#   '26',
#   'октябрь',
#   'музыкант',
#   'группа',
#   'подхватить',
#   'неизвестный',
#   'вирус',
#   'госпитализировать',
#   'боткинский',
#   'больница',
#   'настоящее',
#   'время',
#   'проходить',
#   'тест',
#   '``',
#   'свиной',
#   'грипп',
#   "''",
#   'вскоре',
#   'недомогание',
#   'почувствовать',
#   'остальной',
#   'участник',
#   '``',
#   'аквариум',
#   "''",
#   'из-за',
#   'болезнь',
#   'также',
#   'отменный',
#   'запланировать',
#   'петербург',
#   '29',
#   'октябрь',
#   'концерт',
#   'коллектив',
#   '``',
#   'welcome',
#   'to',
#   'the',
#   'club',
#   "''",
#   'сайд-проект',
#   'гитарист',
#   '``',
#   'аквариум',
#   "''",
#   'игорь',
#   'тимофеев',
#   'перкуссионист',
#   'олег',
#   'шар',
#   'согласно',
#   'информация',
#   'сайт',
#   '``',
#   'аквариум',
#   "''",
#   'ближний',
#   'выступление',
#   'группа',
#   'рамка',
#   'тур',
#   'поддержка',
#   'новое',
#   'альбом',
#   '``',
#   'пушкинский',
#   '10',
#   "''",
#   'должный',
#   'состояться',
#   '6',
#   '11',
#   '16',
#   '17',
#   '19',
#   'ноябрь',
#   'лондон',
#   'уфа',
#   'ижевск',
#   'киров',
#   'вологда',
#   'быть',
#   'отменить',
#   'перенести',
#   'из-за',
#   'болезнь',
#   'музыкант',
#   'пока',
#   'неизвестно'],
#  ['министр',
#   'промышленность',
#   'торговля',
#   'денис',
#   'мантур',
#   'заявить',
#   'отечественный',
#   'зарубежный',
#   'региональный',
#   'партнёр',
#   'проявлять',
#   'интерес',
#   'покупка',
#   'самолёт',
#   'sukhoi',
#   'superjet',
#   '100',
#   'ssj-100',
#   'передавать',
#   'интерфакс',
#   'по',
#   'слово',
#   'произойти',
#   'май',
#   'катастрофа',
#   'ssj-100',
#   'московский',
#   'аэропорт',
#   'шереметьево',
#   'повлиять',
#   'интерес',
#   'заказчик',
#   'это',
#   'самолёт',
#   'оставаться',
#   'перспективный',
#   'товар',
#   'точка',
#   'зрение',
#   'требование',
#   'рынок',
#   'имя',
#   'назвать',
#   'мочь',
#   'это',
#   'конфиденциальный',
#   'информация',
#   'но',
#   'интерес',
#   'ssj-100',
#   'это',
#   'факт',
#   'подчеркнуть',
#   'министр',
#   'отметить',
#   'основной',
#   'поставка',
#   'запланировать',
#   'два',
#   'половина',
#   '2019',
#   'год',
#   'вывод',
#   'причина',
#   'катастрофа',
#   'мантур',
#   'делать',
#   'отказаться',
#   'завершение',
#   'расследование',
#   'при',
#   'добавить',
#   'соответствие',
#   'предварительный',
#   'отчёт',
#   'межгосударственный',
#   'авиационный',
#   'комитет',
#   'самолёт',
#   'управлять',
#   'система',
#   'работать',
#   'ранее',
#   'август',
#   'сообщаться',
#   'мексиканский',
#   'компания',
#   'interjet',
#   'являться',
#   'последний',
#   'иностранный',
#   'эксплуатант',
#   'российский',
#   'самолёт',
#   'искать',
#   'покупатель',
#   'свой',
#   'борт',
#   'поздний',
#   'стать',
#   'известно',
#   'организация',
#   'рассматривать',
#   'вопрос',
#   'отказ',
#   'sukhoi',
#   'superjet',
#   'частичный',
#   'перераспределение',
#   'флот',
#   'авиакомпания',
#   'в',
#   'апрель',
#   'появиться',
#   'информация',
#   'покупать',
#   'самолёт',
#   'отказаться',
#   'словенский',
#   'авиакомпания',
#   'adria',
#   'airways',
#   'до',
#   'sukhoi',
#   'superjet',
#   'также',
#   'отказаться',
#   'бельгийский',
#   'brussels',
#   'airlines',
#   'ирландский',
#   'cityjet',
#   'в',
#   'начало',
#   'май',
#   'sukhoi',
#   'superjet',
#   '100',
#   'потерпеть',
#   'крушение',
#   'московский',
#   'аэропорт',
#   'шереметьево',
#   'в',
#   'результат',
#   'происшествие',
#   'погибнуть',
#   '41',
#   'человек'],
#  ['начинать',
#   '2005',
#   'год',
#   'россия',
#   'вручаться',
#   '40',
#   'премия',
#   'правительство',
#   'рф',
#   'область',
#   'наука',
#   'техника',
#   'число',
#   '10',
#   'премия',
#   'работа',
#   'сфера',
#   'оборона',
#   'безопасность',
#   'как',
#   'сообщаться',
#   'официальный',
#   'сайт',
#   'федеральный',
#   'орган',
#   'исполнительный',
#   'власть',
#   'рф',
#   'размер',
#   'каждый',
#   'премия',
#   'составить',
#   '1',
#   'миллион',
#   'рубль',
#   'расход',
#   'выплата',
#   'премия',
#   'быть',
#   'покрываться',
#   'счёт',
#   'средство',
#   'выделить',
#   'федеральный',
#   'бюджет',
#   'нужда',
#   'министерство',
#   'образование',
#   'наука',
#   'российский',
#   'федерация',
#   'согласно',
#   'положение',
#   'премия',
#   'являться',
#   'средство',
#   'поощрение',
#   'учёный',
#   'специалист',
#   'присуждаться',
#   'ежегодно',
#   'следующий',
#   'достижение',
#   'научно-исследовательский',
#   'опытно-конструкторский',
#   'работа',
#   'завершиться',
#   'создание',
#   'широкий',
#   'применение',
#   'производство',
#   'принципиально',
#   'новый',
#   'технология',
#   'техника',
#   'прибор',
#   'оборудование',
#   'материал',
#   'вещество',
#   'практический',
#   'реализация',
#   'изобретение',
#   'открывать',
#   'новое',
#   'направление',
#   'техника',
#   'технология',
#   'крупный',
#   'реализовать',
#   'практика',
#   'научно-технический',
#   'разработка',
#   'область',
#   'производство',
#   'переработка',
#   'хранение',
#   'сельскохозяйственный',
#   'продукция',
#   'высокий',
#   'результат',
#   'разработка',
#   'практический',
#   'применение',
#   'новый',
#   'метод',
#   'средство',
#   'медицина',
#   'здравоохранение',
#   'научный',
#   'проектно-конструкторский',
#   'технологический',
#   'достижение',
#   'область',
#   'строительство',
#   'архитектура',
#   'жилищно-коммунальный',
#   'хозяйство',
#   'научно-технический',
#   'исследование',
#   'разработка',
#   'интерес',
#   'оборона',
#   'безопасность',
#   'страна',
#   'результат',
#   'который',
#   'использовать',
#   'создание',
#   'совершенный',
#   'военный',
#   'специальный',
#   'техника',
#   'работа',
#   'являться',
#   'значительный',
#   'вклад',
#   'решение',
#   'проблема',
#   'экология',
#   'охрана',
#   'природа',
#   'научно-исследовательский',
#   'разработка',
#   'содействовать',
#   'повышение',
#   'эффективность',
#   'реальный',
#   'сектор',
#   'экономика',
#   'присуждение',
#   'премия',
#   'производиться',
#   'решение',
#   'правительство',
#   'основание',
#   'предложение',
#   'межведомственный',
#   'совет',
#   'присуждение',
#   'премия',
#   'который',
#   'ежегодно',
#   'январь',
#   'объявлять',
#   'средство',
#   'массовый',
#   'информация',
#   'очередной',
#   'конкурс',
#   'работа',
#   'соискание',
#   'премия',
#   'область',
#   'образование'],
#  ['россия',
#   'ответить',
#   'высылка',
#   'свой',
#   'дипломат',
#   'болгария',
#   'сообщить',
#   'заместитель',
#   'министр',
#   'иностранный',
#   'дело',
#   'россия',
#   'александр',
#   'грушко',
#   'он',
#   'слово',
#   'приводить',
#   'тасс',
#   'грушко',
#   'сообщить',
#   'быть',
#   'принять',
#   'мера',
#   'согласно',
#   'дипломатический',
#   'практика',
#   'посольство',
#   'россия',
#   'болгария',
#   'сообщить',
#   'свой',
#   'страница',
#   'facebook',
#   'получение',
#   'нота',
#   'болгарский',
#   'мид',
#   'ведомство',
#   'объявить',
#   'сотрудник',
#   'российский',
#   'посольство',
#   'персона',
#   'нона',
#   'грат',
#   '28',
#   'октябрь',
#   'сообщаться',
#   'болгария',
#   'попросить',
#   'россия',
#   'отозвать',
#   'один',
#   'свой',
#   'дипломат',
#   'прокуратура',
#   'возбудить',
#   'уголовный',
#   'дело',
#   'против',
#   'россиянин',
#   'обвинить',
#   'шпионаж',
#   'поздний',
#   'день',
#   'болгарский',
#   'ведомство',
#   'сообщить',
#   'шпионаж',
#   'российский',
#   'посольство',
#   'заниматься',
#   'некий',
#   'один',
#   'секретарь',
#   'учреждение',
#   'сотрудник',
#   'якобы',
#   'проводить',
#   'встреча',
#   'гражданин',
#   'болгария',
#   'работник',
#   'некий',
#   'организация',
#   'который',
#   'иметь',
#   'доступ',
#   'секретный',
#   'информация',
#   'болгария',
#   'евросоюз',
#   'нато']]

# %%
import gensim
from gensim import corpora
from pprint import pprint
from gensim import models
from gensim.models import LdaModel, LdaMulticore
from gensim.models import LsiModel
import pickle
from pprint import pprint

# %%
mydict = corpora.Dictionary(all_tokens_list)
mycorpus = [mydict.doc2bow(doc) for doc in all_tokens_list]
import pickle
pickle.dump(mycorpus, open('corpus1.pkl', 'wb'))
mydict.save('dictionary1.gensim')
ldamodel = gensim.models.ldamodel.LdaModel(corpus=mycorpus,
                                               id2word=mydict,
                                               num_topics=10,
                                               random_state=100,
                                               update_every=1,
                                               chunksize=100,
                                               passes=10,
                                               alpha='auto',
                                               per_word_topics=True)
ldamodel.save('lda_model_10.gensim')
pprint(ldamodel.print_topics())
# Out:
# [(0,
#   '0.022*"год" + 0.017*"в" + 0.017*"педофилия" + 0.011*"касаться" + '
#   '0.011*"детский" + 0.011*"ватикан" + 0.011*"священник" + 0.011*"случай" + '
#   '0.006*"назвать" + 0.006*"сообщать"'),
#  (1,
#   '0.039*"аэрофлот" + 0.031*"tour" + 0.031*"tez" + 0.020*"система" + '
#   '0.020*"отключить" + 0.020*"бронирование" + 0.016*"гарантия" + '
#   '0.016*"туроператор" + 0.012*"в" + 0.012*"также"'),
#  (2,
#   '0.002*"\'\'" + 0.002*"аэрофлот" + 0.001*"``" + 0.001*"tez" + 0.001*"также" '
#   '+ 0.001*"в" + 0.001*"tour" + 0.001*"бронирование" + 0.001*"система" + '
#   '0.001*"из-за"'),
#  (3,
#   '0.030*"журналист" + 0.026*"украина" + 0.017*"нацгвардия" + '
#   '0.017*"российский" + 0.013*"звезда" + 0.013*"блокпост" + 0.013*"телеканал" '
#   '+ 0.009*"информация" + 0.009*"малышев" + 0.009*"связь"'),
#  (4,
#   '0.002*"\'\'" + 0.002*"``" + 0.001*"аэрофлот" + 0.001*"tour" + 0.001*"tez" + '
#   '0.001*"аквариум" + 0.001*"чипсет" + 0.001*"отключить" + 0.001*"также" + '
#   '0.001*"бронирование"'),
#  (5,
#   '0.001*"nvidia" + 0.001*"чипсет" + 0.001*"премия" + 0.001*"год" + '
#   '0.001*"компания" + 0.001*"информация" + 0.001*"выпуск" + 0.001*"платформа" '
#   '+ 0.001*"ранее" + 0.001*"производство"'),
#  (6,
#   '0.045*"``" + 0.045*"\'\'" + 0.023*"ходорковский" + 0.018*"аквариум" + '
#   '0.010*"ноябрь" + 0.010*"из-за" + 0.010*"болезнь" + 0.010*"октябрь" + '
#   '0.008*"генпрокуратура" + 0.008*"адвокат"'),
#  (7,
#   '0.024*"премия" + 0.018*"nvidia" + 0.018*"чипсет" + 0.012*"информация" + '
#   '0.012*"область" + 0.012*"средство" + 0.012*"техника" + 0.012*"разработка" + '
#   '0.012*"работа" + 0.009*"компания"'),
#  (8,
#   '0.029*"болгария" + 0.023*"россия" + 0.023*"сообщить" + 0.018*"посольство" + '
#   '0.017*"свой" + 0.012*"российский" + 0.012*"один" + 0.012*"сотрудник" + '
#   '0.012*"ведомство" + 0.012*"дело"'),
#  (9,
#   '0.013*"сентябрь" + 0.013*"в" + 0.013*"самолёт" + 0.011*"год" + '
#   '0.011*"журнал" + 0.011*"специальный" + 0.011*"11" + 0.010*"человек" + '
#   '0.010*"это" + 0.010*"sukhoi"')]

# %%
dictionary = corpora.Dictionary(all_tokens_list)
corpus = [dictionary.doc2bow(text) for text in all_tokens_list]
tfidf = models.TfidfModel(corpus, smartirs = 'ntc')
tfidf_model = tfidf[corpus]
lsi_model = LsiModel(corpus = tfidf_model, id2word = dictionary, num_topics = 7, decay = 0.5)
pprint(lsi_model.print_topics(-1, 10))
# Out:
# [(0,
#   '0.252*"ходорковский" + 0.225*"``" + 0.225*"\'\'" + 0.170*"аквариум" + '
#   '0.131*"аэрофлот" + 0.131*"болгария" + 0.128*"сентябрь" + 0.117*"журналист" '
#   '+ 0.105*"tour" + 0.105*"tez"'),
#  (1,
#   '-0.224*"ходорковский" + -0.211*"\'\'" + -0.211*"``" + -0.200*"аквариум" + '
#   '0.164*"болгария" + 0.133*"superjet" + 0.133*"sukhoi" + 0.129*"nvidia" + '
#   '0.129*"чипсет" + 0.123*"самолёт"'),
#  (2,
#   '0.235*"украина" + 0.207*"журналист" + -0.203*"аэрофлот" + 0.183*"болгария" '
#   '+ -0.162*"tour" + -0.162*"tez" + -0.160*"чипсет" + -0.160*"nvidia" + '
#   '0.156*"нацгвардия" + 0.133*"посольство"'),
#  (3,
#   '-0.217*"чипсет" + -0.217*"nvidia" + -0.202*"премия" + 0.191*"болгария" + '
#   '0.156*"аэрофлот" + -0.155*"сентябрь" + 0.125*"tez" + 0.125*"tour" + '
#   '-0.124*"журнал" + 0.109*"педофилия"'),
#  (4,
#   '0.273*"премия" + 0.209*"педофилия" + 0.140*"детский" + 0.140*"ватикан" + '
#   '0.140*"касаться" + 0.140*"священник" + 0.137*"техника" + 0.137*"область" + '
#   '0.137*"средство" + 0.137*"разработка"'),
#  (5,
#   '0.266*"nvidia" + 0.266*"чипсет" + -0.263*"премия" + -0.182*"аэрофлот" + '
#   '-0.146*"tez" + -0.146*"tour" + 0.146*"педофилия" + 0.133*"платформа" + '
#   '0.133*"amd" + -0.132*"область"'),
#  (6,
#   '-0.256*"nvidia" + -0.256*"чипсет" + -0.204*"болгария" + 0.180*"сентябрь" + '
#   '0.144*"журнал" + -0.135*"премия" + -0.128*"amd" + -0.128*"платформа" + '
#   '0.114*"журналист" + 0.108*"событие"')]

# %%
for i in sample_df['clean']:
    bgfd = nltk.FreqDist(i)
    print(bgfd.most_common(10))
# Out:
# [('ходорковский', 9), ('``', 5), ("''", 5), ('генпрокуратура', 3), ('ноябрь', 3), ('адвокат', 3), ('записка', 3), ('россия', 2), ('следствие', 2), ('уголовный', 2)]
# [('год', 4), ('в', 3), ('педофилия', 3), ('ватикан', 2), ('детский', 2), ('случай', 2), ('касаться', 2), ('священник', 2), ('обнаружить', 1), ('порнография', 1)]
# [('nvidia', 6), ('чипсет', 6), ('компания', 3), ('информация', 3), ('платформа', 3), ('amd', 3), ('ранее', 2), ('выпуск', 2), ('риццо', 2), ('время', 2)]
# [('журналист', 7), ('украина', 6), ('российский', 4), ('нацгвардия', 4), ('телеканал', 3), ('звезда', 3), ('блокпост', 3), ('задержать', 2), ('суббота', 2), ('наблюдение', 2)]
# [('аэрофлот', 10), ('tez', 8), ('tour', 8), ('отключить', 5), ('система', 5), ('бронирование', 5), ('туроператор', 4), ('гарантия', 4), ('авиакомпания', 3), ('также', 3)]
# [('сентябрь', 5), ('журнал', 4), ('11', 4), ('специальный', 4), ('time', 3), ('теракт', 3), ('2001', 3), ('год', 3), ('номер', 3), ('человек', 3)]
# [('``', 13), ("''", 13), ('аквариум', 7), ('из-за', 4), ('болезнь', 4), ('группа', 3), ('концерт', 3), ('музыкант', 3), ('октябрь', 3), ('борис', 2)]
# [('самолёт', 5), ('sukhoi', 4), ('superjet', 4), ('интерес', 3), ('ssj-100', 3), ('это', 3), ('отказаться', 3), ('в', 3), ('министр', 2), ('мантур', 2)]
# [('премия', 8), ('область', 4), ('техника', 4), ('работа', 4), ('средство', 4), ('разработка', 4), ('правительство', 2), ('рф', 2), ('наука', 2), ('оборона', 2)]
# [('болгария', 5), ('россия', 4), ('сообщить', 4), ('свой', 3), ('посольство', 3), ('дипломат', 2), ('дело', 2), ('грушко', 2), ('болгарский', 2), ('ведомство', 2)]

# %%
bigram = gensim.models.phrases.Phrases(all_tokens_list, min_count=3, threshold=10)
print(bigram[all_tokens_list[0]])
# Out:
# ['генпрокуратура', 'россия', 'завершить', 'предварительный', 'следствие', 'уголовный', 'дело', 'отношение', 'бывший', 'глава', 'нк', '``', 'юкос', "''", 'михаил', 'ходорковский', 'о', 'ходорковский', 'объявить', '25', 'ноябрь', 'присутствие', 'адвокат', 'сообщить', 'информационный', 'агентство', '``', 'интерфакс', "''", 'официальный', 'представитель', 'генпрокуратура', 'обвинять', 'вместе', 'адвокат', 'начинать', 'ознакомление', 'материал', 'дело', 'генпрокуратура', 'обвинять', 'ходорковский', 'семь', 'статья', 'уголовный', 'кодекс', 'россия', 'число', 'хищение', 'путём', 'мошенничество', 'крупный', 'размер', 'уклонение', 'уплата', 'налог', 'самый', '``', 'юкос', "''", 'лично', 'ходорковский', 'кроме', 'ходорковский', 'предъявить', 'обвинение', 'злостный', 'неисполнение', 'вступить', 'законный', 'сила', 'решение', 'суд', 'причинение', 'имущественный', 'ущерб', 'собственник', 'путём', 'обман', 'подделка', 'официальный', 'документ', 'совершенный', 'неоднократно', 'присвоение', 'растрата', 'михаил', 'ходорковский', 'задержать', '25', 'октябрь', '2003', 'год', 'новосибирск', 'доставить', 'москва', 'в', 'день', 'басманный', 'суд', 'москва', 'выдать', 'санкция', 'арест', 'с', 'тот', 'пора', 'ходорковский', 'находиться', 'стража', 'а', '24', 'ноябрь', 'ежедневный', 'газета', '``', 'коммерсант', "''", 'опубликовать', 'текст', 'записка', 'отобрать', 'выход', 'сизый', 'адвокат', 'ходорковский', 'ольга', 'артюхов', 'этот', 'записка', 'который', 'сообщаться', 'написать', 'ходроковский', '``', 'содержимый', 'инструкция', 'противодействие', 'следствие', "''", 'отобрать', 'артюхин', '11', 'ноябрь', 'как', 'заключать', 'газета', 'содержание', 'дать', 'записка', 'оказаться', 'распоряжение', 'издание', 'следовать', 'вряд', 'мочь', 'написать', 'ходорковский']

# %%
from nltk import ngrams

for i in sample_df['clean']:
    grams = ngrams(i, 2)
    for gram in grams:
        bgfd = nltk.FreqDist(gram)
        print(bgfd.most_common(10))
# Out:
# [('генпрокуратура', 1), ('россия', 1)]
# [('россия', 1), ('завершить', 1)]
# [('завершить', 1), ('предварительный', 1)]
# [('предварительный', 1), ('следствие', 1)]
# [('следствие', 1), ('уголовный', 1)]
# [('уголовный', 1), ('дело', 1)]
# [('дело', 1), ('отношение', 1)]
# [('отношение', 1), ('бывший', 1)]
# [('бывший', 1), ('глава', 1)]
# [('глава', 1), ('нк', 1)]
# [('нк', 1), ('``', 1)]
# [('``', 1), ('юкос', 1)]
# [('юкос', 1), ("''", 1)]
# [("''", 1), ('михаил', 1)]
# [('михаил', 1), ('ходорковский', 1)]
# [('ходорковский', 1), 
# [('сообщить', 1), ('шпионаж', 1)]
# [('шпионаж', 1), ('российский', 1)]
# [('российский', 1), ('посольство', 1)]
# [('посольство', 1), ('заниматься', 1)]
# [('заниматься', 1), ('некий', 1)]
# [('некий', 1), ('один', 1)]
# [('один', 1), ('секретарь', 1)]
# [('секретарь', 1), ('учреждение', 1)]
# [('учреждение', 1), ('сотрудник', 1)]
# [('сотрудник', 1), ('якобы', 1)]
# [('якобы', 1), ('проводить', 1)]
# [('проводить', 1), ('встреча', 1)]
# [('встреча', 1), ('гражданин', 1)]
# [('гражданин', 1), ('болгария', 1)]
# [('болгария', 1), ('работник', 1)]
# [('работник', 1), ('некий', 1)]
# [('некий', 1), ('организация', 1)]
# [('организация', 1), ('который', 1)]
# [('который', 1), ('иметь', 1)]
# [('иметь', 1), ('доступ', 1)]
# [('доступ', 1), ('секретный', 1)]
# [('секретный', 1), ('информация', 1)]
# [('информация', 1), ('болгария', 1)]
# [('болгария', 1), ('евросоюз', 1)]
# [('евросоюз', 1), ('нато', 1)]

# %%
bigram = gensim.models.Phrases(all_tokens_list, min_count=5, threshold=100)

# %%
print(bigram[all_tokens_list[0]])
# Out:
# ['генпрокуратура', 'россия', 'завершить', 'предварительный', 'следствие', 'уголовный', 'дело', 'отношение', 'бывший', 'глава', 'нк', '``', 'юкос', "''", 'михаил', 'ходорковский', 'о', 'ходорковский', 'объявить', '25', 'ноябрь', 'присутствие', 'адвокат', 'сообщить', 'информационный', 'агентство', '``', 'интерфакс', "''", 'официальный', 'представитель', 'генпрокуратура', 'обвинять', 'вместе', 'адвокат', 'начинать', 'ознакомление', 'материал', 'дело', 'генпрокуратура', 'обвинять', 'ходорковский', 'семь', 'статья', 'уголовный', 'кодекс', 'россия', 'число', 'хищение', 'путём', 'мошенничество', 'крупный', 'размер', 'уклонение', 'уплата', 'налог', 'самый', '``', 'юкос', "''", 'лично', 'ходорковский', 'кроме', 'ходорковский', 'предъявить', 'обвинение', 'злостный', 'неисполнение', 'вступить', 'законный', 'сила', 'решение', 'суд', 'причинение', 'имущественный', 'ущерб', 'собственник', 'путём', 'обман', 'подделка', 'официальный', 'документ', 'совершенный', 'неоднократно', 'присвоение', 'растрата', 'михаил', 'ходорковский', 'задержать', '25', 'октябрь', '2003', 'год', 'новосибирск', 'доставить', 'москва', 'в', 'день', 'басманный', 'суд', 'москва', 'выдать', 'санкция', 'арест', 'с', 'тот', 'пора', 'ходорковский', 'находиться', 'стража', 'а', '24', 'ноябрь', 'ежедневный', 'газета', '``', 'коммерсант', "''", 'опубликовать', 'текст', 'записка', 'отобрать', 'выход', 'сизый', 'адвокат', 'ходорковский', 'ольга', 'артюхов', 'этот', 'записка', 'который', 'сообщаться', 'написать', 'ходроковский', '``', 'содержимый', 'инструкция', 'противодействие', 'следствие', "''", 'отобрать', 'артюхин', '11', 'ноябрь', 'как', 'заключать', 'газета', 'содержание', 'дать', 'записка', 'оказаться', 'распоряжение', 'издание', 'следовать', 'вряд', 'мочь', 'написать', 'ходорковский']
